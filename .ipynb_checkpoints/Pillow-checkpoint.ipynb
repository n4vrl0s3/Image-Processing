# %%
from PIL import Image
from matplotlib import pyplot as plt

gambar = Image.open("./Assets/buildings.jpg")

# menampilkan gambar
display(gambar)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1273>

# %%
#merubah gambar ke mode L, yang artinya memiliki warna 8bit yaitu hitam dan putih
grayImage = gambar.convert('L')

#menampilkan gambar yang sudah di ubah menjadi grayscale
display(grayImage)
# Out:
# <PIL.Image.Image image mode=L size=1920x1273>
