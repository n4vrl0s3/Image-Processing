# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('Assets/cat.jpg')

# 1. Grayscale Image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 2. Negative Image
negative_image = 255 - image

# 3. Binary Image (Thresholding)
_, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)

# 4. Image Translation
rows, cols = image.shape[:2]
translation_matrix = np.float32([[1, 0, 50], [0, 1, 50]])  # Translate 50 pixels on both x and y axes
translated_image = cv2.warpAffine(image, translation_matrix, (cols, rows))

# Display the results
titles = ['Original Image', 'Grayscale Image', 'Negative Image', 'Binary Image', 'Translated Image']
images = [image, gray_image, negative_image, binary_image, translated_image]

plt.figure(figsize=(10, 8))
for i in range(5):
    plt.subplot(2, 3, i + 1)
    if i == 1:
        plt.imshow(images[i], cmap='gray')  # Grayscale image
    else:
        plt.imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for proper display
    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()
